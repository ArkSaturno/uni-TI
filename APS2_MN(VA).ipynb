# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkSaturno/uni-TI/blob/main/APS2_MN(VA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import imageio
import numpy as np 
image = imageio.imread("https://cdn.britannica.com/67/148167-050-F596E6F2/Marcus-Aurelius-statue-Rome-Piazza-del-Campidoglio.jpg");
imageToMatrice = np.asarray(image) 
print(imageToMatrice.shape)
# Out:
# (1600, 1265, 3)

# %%
arr = np.array([[1600, 1265, 3]], dtype=np.float32) 
  
print("Array original:") 
print(arr) 
U, s, V = np.linalg.svd(arr, full_matrices=False) 
print("\nFator do array decomposto por valor singular:") 
print("\nU=", U, "\n\ns=", s, "\n\nV=", V)
# Out:
# Array original:
# [[1600. 1265.    3.]]
#
# Fator do array decomposto por valor singular:
#
# U= [[-1.]]
#
# s= [2039.6652]
#
# V= [[-0.7844425  -0.62019986 -0.00147083]]

# %%
import numpy as np
import imageio

image = imageio.imread("https://cdn.britannica.com/67/148167-050-F596E6F2/Marcus-Aurelius-statue-Rome-Piazza-del-Campidoglio.jpg");

A = image[:, :, 1]
# %time u, s, v = np.linalg.svd(A, full_matrices = 0);

import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplots(1, 2, figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Imagem original')
plt.axis('off')

plt.subplot(1, 2, 2)
rank = 60
plt.imshow(image)
plt.title('Rank 60')
plt.axis('off')
plt.show()

plt.subplot(1, 2, 2)
rank = 70
plt.imshow(image)
plt.title('Rank 70')
plt.axis('off')
plt.show()

plt.subplot(1, 2, 2)
rank = 80
plt.imshow(image)
plt.title('Rank 80')
plt.axis('off')
plt.show()
# Out:
# CPU times: user 3.39 s, sys: 505 ms, total: 3.89 s
# Wall time: 2.04 s
