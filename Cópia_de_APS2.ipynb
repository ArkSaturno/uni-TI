# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkSaturno/uni-TI/blob/main/C%C3%B3pia_de_APS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
image = imageio.imread("https://cdn.dicionariopopular.com/imagens/pai-de-familia-memes-7.jpg?auto_optimize=low");
imageToMatrice = np.asarray(image) 
print(imageToMatrice.shape)
# Out:
# (405, 579, 3)

# %%
arr = np.array([[405, 579, 3]], dtype=np.float32) 
  
print("Original array:") 
print(arr) 
U, s, V = np.linalg.svd(arr, full_matrices=False) 
print("\nFator do array decomposto por valor singular:") 
print("\nU=", U, "\n\ns=", s, "\n\nV=", V)
# Out:
# Original array:
# [[405. 579.   3.]]
#
# Fator do array decomposto por valor singular:
#
# U= [[-1.]]
#
# s= [706.59393]
#
# V= [[-0.5731722  -0.819424   -0.00424572]]

# %%
import numpy as np
import imageio

image = imageio.imread("https://cdn.dicionariopopular.com/imagens/pai-de-familia-memes-7.jpg?auto_optimize=low");

A = image[:, :, 1]
# %time u, s, v = np.linalg.svd(A, full_matrices = 0);

import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplots(1, 2, figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Imagem original')
plt.axis('off')

plt.subplot(1, 2, 2)
rank = 60
plt.imshow(image)
plt.title('Rank 60')
plt.axis('off')
plt.show()

plt.subplot(1, 2, 2)
rank = 70
plt.imshow(image)
plt.title('Rank 70')
plt.axis('off')
plt.show()

plt.subplot(1, 2, 2)
rank = 80
plt.imshow(image)
plt.title('Rank 80')
plt.axis('off')
plt.show()
# Out:
# CPU times: user 91.1 ms, sys: 19.3 ms, total: 110 ms
# Wall time: 57 ms
